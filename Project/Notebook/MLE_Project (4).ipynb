# %% [markdown]
# #MLE Semester Project
# #Travis Johnson
# #662018371

# %% [markdown]
# #Project: Stock Market Prediction

# %% [markdown]
# #Downloading S&P 500 Historical Data for the Last 10 Years

# %%
# Installing yfinance
# !pip install yfinance

import yfinance as yf
import pandas as pd
import datetime
import os
import requests
from bs4 import BeautifulSoup

# Getting S&P 500 tickers from Wikipedia
def get_sp500_tickers():
    url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    html = requests.get(url).text
    soup = BeautifulSoup(html, 'html.parser')
    table = soup.find('table', {'id': 'constituents'})
    tickers = []

    for row in table.findAll('tr')[1:]:
        symbol = row.findAll('td')[0].text.strip()
        symbol = symbol.replace('.', '-')  # Yahoo Finance uses '-' not '.'
        tickers.append(symbol)

    return tickers

# Downloading and save last 10 years of daily data
def download_sp500_data(tickers, save_dir="sp500_data"):
    os.makedirs(save_dir, exist_ok=True)
    end_date = datetime.datetime.today()
    start_date = end_date - datetime.timedelta(days=365 * 10)

    for ticker in tickers:
        try:
            print(f"Downloading {ticker}")
            df = yf.download(ticker, start=start_date.strftime('%Y-%m-%d'), end=end_date.strftime('%Y-%m-%d'))
            df.reset_index(inplace=True)  # Convert 'Date' index into column
            df["Ticker"] = ticker
            df.to_csv(f"{save_dir}/{ticker}.csv", index=False)
        except Exception as e:
            print(f"Failed for {ticker}: {e}")

    print("All files saved correctly with 'Date' column.")

# Running everything
tickers = get_sp500_tickers()
download_sp500_data(tickers)
# Out:
# ...
# <ipython-input-1-15db00155b5d>:19: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   for row in table.findAll('tr')[1:]:
# <ipython-input-1-15db00155b5d>:20: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   symbol = row.findAll('td')[0].text.strip()
# ...
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# ...
# [*********************100%***********************]  1 of 1 completed
# ...
# [*********************100%***********************]  1 of 1 completed
# ...
# [*********************100%***********************]  1 of 1 completed
# ...
# [*********************100%***********************]  1 of 1 completed
# ...
# [*********************100%***********************]  1 of 1 completed
# ...
# [*********************100%***********************]  1 of 1 completed
# ...

# %% [markdown]
# Note: Collecting the Data for the entire S&P for the last 10 Years takes about 2 minutes to execute

# %%
import yfinance as yf

# Re-downloading full AAPL data from 2014 to today for any errors
df = yf.download("AAPL", start="2014-01-01")
df.reset_index(inplace=True)
df["Ticker"] = "AAPL"

# Saving corrected data to CSV
df.to_csv("sp500_data/AAPL.csv", index=False)
print("AAPL data re-downloaded and saved.")
# Out:
# [*********************100%***********************]  1 of 1 completed
# AAPL data re-downloaded and saved.

# %%
df_check = pd.read_csv("sp500_data/AAPL.csv", parse_dates=["Date"])
print("AAPL date range:", df_check["Date"].min(), "→", df_check["Date"].max())
# Out:
# AAPL date range: 2014-01-02 00:00:00 → 2025-04-23 00:00:00

# %% [markdown]
# #Downloading Economic Indicators

# %%
# Installing fredapi
# !pip install fredapi

# Importing libraries
from fredapi import Fred
import pandas as pd
import datetime

# Connectting to FRED with my custom API key
fred = Fred(api_key='0e376b94378b31d331908069cef3c2d8')

# Defining the date range
start_date = "2014-01-01"
end_date = datetime.datetime.today().strftime("%Y-%m-%d")

# Economic indicators to download
indicators = {
    "FEDFUNDS": "Interest_Rate",         # Federal Funds Rate
    "CPIAUCSL": "CPI",                   # Consumer Price Index
    "UNRATE": "Unemployment_Rate",       # Unemployment Rate
    "GS10": "10Y_Treasury",              # 10-Year Treasury Rate
    "GDPC1": "Real_GDP"                  # Real Gross Domestic Product
}

economic_data = pd.DataFrame()

# Downloading the data and merging into one DataFrame
for code, name in indicators.items():
    series = fred.get_series(code, start_date, end_date)
    df = series.to_frame(name)
    economic_data = pd.concat([economic_data, df], axis=1)

# Formatting and Saving
economic_data.index.name = "Date"
economic_data.reset_index(inplace=True)
economic_data["Date"] = pd.to_datetime(economic_data["Date"])
economic_data.to_csv("economic_indicators.csv", index=False)

print("Economic indicators saved to 'economic_indicators.csv'")
# Out:
# ...
# Economic indicators saved to 'economic_indicators.csv'

# %% [markdown]
# #Adding News Sentiment Analysis with VADER

# %%
# Installing NLTK and download VADER lexicon
# !pip install nltk
import nltk
nltk.download('vader_lexicon')
# Out:
# ...
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# #Setup Sentiment Analyzer

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd

# Initializing VADER
sia = SentimentIntensityAnalyzer()

# %% [markdown]
# #Loading News Headlines for the Last 365 Days Via NewsAPI, and FinnhubAPI

# %%
import requests
import pandas as pd
import datetime
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk

# Installing and loading VADER
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()

# API KEYS
newsapi_key = "75e4e306d7ed4839a925e631f0507058"
finnhub_key = "cvlkmbpr01qj3ume0540cvlkmbpr01qj3ume054g"

# Date Range (last 365 days)
end_date = datetime.date.today()
start_date = end_date - datetime.timedelta(days=365)

# Fetching data from NewsAPI
def fetch_newsapi_data(query="stock market"):
    url = f"https://newsapi.org/v2/everything?q={query}&from={start_date}&to={end_date}&sortBy=publishedAt&language=en&apiKey={newsapi_key}"
    response = requests.get(url)
    articles = response.json().get("articles", [])
    return [{"date": a["publishedAt"][:10], "headline": a["title"]} for a in articles]

# Fetching data from Finnhub (Example: AAPL)
def fetch_finnhub_data(symbol="AAPL"):
    url = f"https://finnhub.io/api/v1/company-news?symbol={symbol}&from={start_date}&to={end_date}&token={finnhub_key}"
    response = requests.get(url)
    articles = response.json()
    return [{"date": datetime.datetime.utcfromtimestamp(a["datetime"]).strftime('%Y-%m-%d'), "headline": a["headline"]} for a in articles]

# Combining news from both sources
newsapi_news = fetch_newsapi_data("stock market")
finnhub_news = fetch_finnhub_data("AAPL")  # You can loop for multiple tickers if needed

all_news = newsapi_news + finnhub_news
news_df = pd.DataFrame(all_news)
news_df["date"] = pd.to_datetime(news_df["date"])

# Applying Sentiment Scoring
news_df["sentiment_score"] = news_df["headline"].apply(lambda x: sia.polarity_scores(x)["compound"])

# Creating the Aggregate Daily Sentiment
daily_sentiment = news_df.groupby("date").agg({"sentiment_score": "mean"}).reset_index()
daily_sentiment.rename(columns={"sentiment_score": "avg_sentiment"}, inplace=True)

# Saving to CSV
daily_sentiment.to_csv("combined_sentiment.csv", index=False)
print("Saved combined sentiment to 'combined_sentiment.csv'")
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Saved combined sentiment to 'combined_sentiment.csv'

# %%
# Check column names in sentiment CSV
sentiment_df = pd.read_csv("combined_sentiment.csv")
print(sentiment_df.columns)
# Out:
# Index(['date', 'avg_sentiment'], dtype='object')

# %% [markdown]
# #Merging Stock, Economic, and Sentiment Data

# %%
# Reloading raw data
stock_df = pd.read_csv("sp500_data/AAPL.csv", parse_dates=["Date"])
econ_df = pd.read_csv("economic_indicators.csv", parse_dates=["Date"])
#sentiment_df = pd.read_csv("combined_sentiment.csv", parse_dates=["Date"])

sentiment_df = pd.read_csv("combined_sentiment.csv")
sentiment_df["Date"] = pd.to_datetime(sentiment_df["date"])


# Dropping any null Dates
stock_df.dropna(subset=["Date"], inplace=True)
econ_df.dropna(subset=["Date"], inplace=True)
sentiment_df.dropna(subset=["Date"], inplace=True)

# Sorting before merge_asof
stock_df.sort_values("Date", inplace=True)
econ_df.sort_values("Date", inplace=True)
sentiment_df.sort_values("Date", inplace=True)

# Merging stock and economic data
merged = pd.merge_asof(stock_df, econ_df, on="Date")

# Merging in sentiment data
merged = pd.merge_asof(merged, sentiment_df[["Date", "avg_sentiment"]], on="Date")

# Saving the final result
merged.to_csv("AAPL_full_merged.csv", index=False)
print("Merged stock + econ + sentiment saved to 'AAPL_full_merged.csv'")
# Out:
# Merged stock + econ + sentiment saved to 'AAPL_full_merged.csv'

# %%
df = pd.read_csv("AAPL_full_merged.csv", parse_dates=["Date"])
print(df.shape, df["Date"].min(), df["Date"].max())
# Out:
# (2844, 13) 2014-01-02 00:00:00 2025-04-23 00:00:00

# %% [markdown]
# #Exploratory Data Analysis

# %% [markdown]
# #Load and Preview Data

# %%
import pandas as pd

# Loading merged dataset
df = pd.read_csv("AAPL_full_merged.csv", parse_dates=["Date"])

# Preview structure
print(df.info())
print(df.describe())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2844 entries, 0 to 2843
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               2844 non-null   datetime64[ns]
#  1   Close              2844 non-null   float64
#  2   High               2844 non-null   float64
#  3   Low                2844 non-null   float64
#  4   Open               2844 non-null   float64
#  5   Volume             2844 non-null   int64
#  6   Ticker             2844 non-null   object
#  7   Interest_Rate      2844 non-null   float64
#  8   CPI                2844 non-null   float64
#  9   Unemployment_Rate  2844 non-null   float64
#  10  10Y_Treasury       2844 non-null   float64
#  11  Real_GDP           925 non-null    float64
#  12  avg_sentiment      7 non-null      float64
# dtypes: datetime64[ns](1), float64(10), int64(1), object(1)
# memory usage: 289.0+ KB
# None
# ...

# %% [markdown]
# #Missing Values Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# #Stock Price Over Time

# %%
plt.figure(figsize=(14, 6))
plt.plot(df["Date"], df["Close"], label="AAPL Close Price")
plt.title("AAPL Stock Price Over Time")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #Sentiment vs. Price Trend

# %%
import matplotlib.pyplot as plt

# Get the date range from the sentiment data
min_date = merged["Date"][merged["avg_sentiment"].notna()].min()
max_date = merged["Date"][merged["avg_sentiment"].notna()].max()

print(merged.columns)


# Filter merged data to that date range
aligned = merged[(merged["Date"] >= min_date) & (merged["Date"] <= max_date)]

# Plotting
fig, ax1 = plt.subplots(figsize=(14, 6))

# Plot stock price
ax1.plot(aligned["Date"], aligned["Close"], color='tab:blue', label="AAPL Close Price", linewidth=2)
ax1.set_xlabel("Date")
ax1.set_ylabel("Price (USD)", color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Plot sentiment
ax2 = ax1.twinx()
ax2.plot(aligned["Date"], aligned["avg_sentiment"], color='tab:orange', label="Sentiment", alpha=0.6)
ax2.set_ylabel("Sentiment Score", color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')

# Styling
fig.suptitle("AAPL Price vs. Sentiment Over Matching Date Range", fontsize=16)
fig.tight_layout()
fig.legend(loc="upper left", bbox_to_anchor=(0.1, 0.9))
plt.grid(True, linestyle='--', alpha=0.3)
plt.show()
# Out:
# Index(['Date', 'Close', 'High', 'Low', 'Open', 'Volume', 'Ticker',
#        'Interest_Rate', 'CPI', 'Unemployment_Rate', '10Y_Treasury', 'Real_GDP',
#        'avg_sentiment'],
#       dtype='object')

# %% [markdown]
# #Correlation Heatmap

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.drop(columns=["Date", "Ticker"]).corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# #Rolling Volatility (30-day)

# %%
df["30d_volatility"] = df["Close"].pct_change().rolling(window=30).std()

plt.figure(figsize=(14, 6))
plt.plot(df["Date"], df["30d_volatility"], label="30-Day Rolling Volatility")
plt.title("Stock Volatility Over Time")
plt.xlabel("Date")
plt.ylabel("Volatility")
plt.grid(True)
plt.show()

# %% [markdown]
# #Modeling to Predict Future Close Price

# %% [markdown]
# #Prepare Data + Lag Features

# %%
import pandas as pd

df = pd.read_csv("AAPL_stock_econ_only.csv", parse_dates=["Date"])

# Dropping rows with any missing economic values
df.dropna(subset=["Close", "Volume", "Interest_Rate", "CPI", "Unemployment_Rate", "10Y_Treasury", "Real_GDP"], inplace=True)

# Lag features
df["Close_lag_1"] = df["Close"].shift(1)
df["Close_lag_2"] = df["Close"].shift(2)
df["Close_lag_3"] = df["Close"].shift(3)

# Dropping NaNs created by lagging
df.dropna(inplace=True)

# Final features & target
features = ["Close_lag_1", "Close_lag_2", "Close_lag_3", "Volume",
            "Interest_Rate", "CPI", "Unemployment_Rate", "10Y_Treasury", "Real_GDP"]
target = "Close"

X = df[features]
y = df[target]

# %% [markdown]
# #Train-Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.2)

print("Train shape:", X_train.shape, "| Test shape:", X_test.shape)
# Out:
# Train shape: (737, 9) | Test shape: (185, 9)

# %% [markdown]
# #Linear Regression (Baseline)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from math import sqrt

lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)

rmse_lr = sqrt(mean_squared_error(y_test, y_pred_lr))
mape_lr = mean_absolute_percentage_error(y_test, y_pred_lr)

print(f"Linear Regression RMSE: {rmse_lr:.2f}, MAPE: {mape_lr:.2%}")
# Out:
# Linear Regression RMSE: 8.82, MAPE: 3.85%

# %% [markdown]
# #XGBoost (Advanced)

# %%
# !pip install xgboost

from xgboost import XGBRegressor

xgb = XGBRegressor(objective="reg:squarederror", n_estimators=100)
xgb.fit(X_train, y_train)
y_pred_xgb = xgb.predict(X_test)

rmse_xgb = sqrt(mean_squared_error(y_test, y_pred_xgb))
mape_xgb = mean_absolute_percentage_error(y_test, y_pred_xgb)

print(f"XGBoost RMSE: {rmse_xgb:.2f}, MAPE: {mape_xgb:.2%}")
# Out:
# ...
# XGBoost RMSE: 37.99, MAPE: 14.58%

# %% [markdown]
# #Plot Actual vs. Predicted

# %%
import matplotlib.pyplot as plt

# Getting corresponding date range for the test set
date_test = df["Date"].iloc[-len(y_test):]

plt.figure(figsize=(14, 6))
plt.plot(date_test, y_test, label="Actual", color="black")
plt.plot(date_test, y_pred_lr, label="Linear Regression", alpha=0.7)
plt.plot(date_test, y_pred_xgb, label="XGBoost", alpha=0.7)
plt.title("Actual vs Predicted Close Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Installing Tensorflow

# %%
# !pip install tensorflow

# %% [markdown]
# #LSTM Model for Stock Price Prediction (30-day window)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# Loading and scaling data ---
df = pd.read_csv("AAPL_stock_econ_only.csv", parse_dates=["Date"])
df.dropna(subset=["Close"], inplace=True)

# Using just the 'Close' column
close_data = df[["Close"]].values

scaler = MinMaxScaler()
scaled_close = scaler.fit_transform(close_data)

# Creating sequences
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

SEQ_LEN = 30  # Use 30 previous days
X, y = create_sequences(scaled_close, SEQ_LEN)

# Train/test split
split = int(len(X) * 0.8)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Building LSTM model
model = Sequential()
model.add(LSTM(50, activation="relu", input_shape=(SEQ_LEN, 1)))
model.add(Dense(1))
model.compile(optimizer="adam", loss="mse")

# Training
history = model.fit(
    X_train, y_train,
    validation_split=0.1,
    epochs=20,
    batch_size=32,
    callbacks=[EarlyStopping(patience=3)],
    verbose=1
)

# Predicting & inverse transform
y_pred_scaled = model.predict(X_test)
y_pred = scaler.inverse_transform(y_pred_scaled)
y_true = scaler.inverse_transform(y_test)

# Plotting
plt.figure(figsize=(14, 6))
plt.plot(y_true, label="Actual", color='black')
plt.plot(y_pred, label="LSTM Prediction", color='blue', alpha=0.7)
plt.title("LSTM Model - Actual vs Predicted Close Price")
plt.xlabel("Time Step")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - loss: 0.0215 - val_loss: 6.7079e-04
# Epoch 2/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.9339e-04 - val_loss: 8.4606e-04
# Epoch 3/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 1.1935e-04 - val_loss: 0.0012
# Epoch 4/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.0935e-04 - val_loss: 5.7718e-04
# Epoch 5/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 9.9622e-05 - val_loss: 5.1204e-04
# Epoch 6/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 9.2229e-05 - val_loss: 5.6269e-04
# Epoch 7/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 8.4532e-05 - val_loss: 6.0772e-04
# Epoch 8/20
# ...

# %% [markdown]
# #Multi-Feature LSTM Modeling Block

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# Loading Data
df = pd.read_csv("AAPL_stock_econ_only.csv", parse_dates=["Date"])

# Selecting relevant features
features = ["Close", "Volume", "Interest_Rate", "CPI",
            "Unemployment_Rate", "10Y_Treasury", "Real_GDP"]

df = df[features].dropna()

# Scaling features
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)

# Creating Sequences
def create_multifeature_sequences(data, seq_length, target_column_index):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length, target_column_index])  # target is 'Close'
    return np.array(X), np.array(y)

SEQ_LEN = 30
target_index = df.columns.get_loc("Close")
X, y = create_multifeature_sequences(scaled_data, SEQ_LEN, target_index)

# Splitting
split = int(len(X) * 0.8)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Building Model
model = Sequential()
model.add(LSTM(64, activation="relu", input_shape=(SEQ_LEN, X.shape[2])))
model.add(Dense(1))
model.compile(optimizer="adam", loss="mse")

# Training
history = model.fit(
    X_train, y_train,
    validation_split=0.1,
    epochs=25,
    batch_size=32,
    callbacks=[EarlyStopping(patience=3)],
    verbose=1
)

# Predicting
y_pred_scaled = model.predict(X_test)
close_scaler = MinMaxScaler()
close_scaler.min_, close_scaler.scale_ = scaler.min_[target_index], scaler.scale_[target_index]
y_pred = y_pred_scaled / close_scaler.scale_ + close_scaler.min_
y_true = y_test.reshape(-1, 1) / close_scaler.scale_ + close_scaler.min_

# Plotting
plt.figure(figsize=(14, 6))
plt.plot(y_true, label="Actual Close", color="black")
plt.plot(y_pred, label="Predicted Close", color="green", alpha=0.7)
plt.title("Multi-Feature LSTM: Actual vs Predicted Close Price")
plt.xlabel("Time Step")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/25
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0374 - val_loss: 0.0013
# Epoch 2/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 3/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.5950e-04 - val_loss: 0.0016
# Epoch 4/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.8548e-04 - val_loss: 0.0016
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step

# %% [markdown]
# Notes: This Multi Feature LSTM uses 7 features, only targeting closing price
